# %% [markdown]
# ## Ввод и вывод
#
# #### Задание 1
#
# На вход: получить из ввода 1 строку, которая содержи 2 числа, разделённых пробелом
#
# На выходе: форматированная строка, которая содержит информацию об исходных числах и сумму 2 чисел
#
# ```python
# 'Сумма чисел 5 и 10 = 15'
# ```
#
# #### Задание 2
#
# На вход: получить из ввода 1 строку, которая содержи 2 слова, разделённых пробелом
#
# На выходе: строка, в которой символ пробела заменён '_'
#
# Придумайте 4 различных способа, как это сделать
#
# #### Задание 3
#
# На вход: получить из ввода 1 строку, которая содержи число в двочной системе счисления, например `101` (десятичная 5)
#
# На выходе: число в десятичной системе счисления

# %% [markdown]
# ## Арифметические операции
#
# #### Задание 1
#
# Вычисление идеального веса человека по росту
#
# [ИМТ](https://ru.wikipedia.org/wiki/%D0%98%D0%BD%D0%B4%D0%B5%D0%BA%D1%81_%D0%BC%D0%B0%D1%81%D1%81%D1%8B_%D1%82%D0%B5%D0%BB%D0%B0)
#
# Пусть идеальный ИМТ это средний нормальный = (25 + 18,5) / 2
#
# На вход: рост
#
# На выходе: вес

# %% [markdown]
# ## Логические типы данных
#
# #### Задание 1
#
# Экзамен
#
# Всего 16 занятий. Максимальный бал за активность - 100, минимальный - 0. Всего 5 тестов с отметкой зачёт/незачёт
#
# На вход. Получить из ввода 3 значения: число посещённых занятий, бал за активность, балы за тесты
#
# На выход: оценка
#
# Условия:
#
# |оценка|посещения, минимум|бал за активность, мимнимум|балы за тесты, минимум|
# |---|---|---|---|
# |5 автомат|16/16|80|4|
# |5|14/16|-|5|
# |4|12/16|-|4|
# |3|10/16|-|3|
# |2|6/16|-|2|

# %% [markdown]
# ## Работа со строками
#
# #### Задание 1
#
# Отрисуйте с использованием f-строк таблицу выше + итог

# %% [markdown]
# ## Условия и циклы
#
# #### Вопрос
# В чём назначение циклов for и while? В чём их отличие?

# %% [markdown]
# #### Задание 1
# Для заданного (фиксированного) слова "звезда" и некоторого числительного, вводимого пользователем через `input` необходимо поставить правильное окончание. Например: 1 звезда, 15 звёзд, 2 звезды.
#
# Можно использовать любые другие слова, кроме "звезда".
#
# Предлагается оформить код в виде цикла `while`. При каждой итерации будем получать через `input`  некоторое число (int), по которому нужно будет применить правильное окончание. Выход из цикла осуществить в случае если `input` получит нечисловой формат
